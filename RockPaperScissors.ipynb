# %%
import cv2
from keras.models import load_model
import numpy as np
model = load_model('keras_model.h5')
cap = cv2.VideoCapture(0)
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

while True: 
    ret, frame = cap.read()
    resized_frame = cv2.resize(frame, (224, 224), interpolation = cv2.INTER_AREA)
    image_np = np.array(resized_frame)
    normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
    data[0] = normalized_image
    prediction = model.predict(data)
    cv2.imshow('frame', frame)
    # Press q to close the window
    if prediction[0][0] > 0.7 :
        print('Rock')
    elif prediction[0][1] > 0.7:
        print('Paper')
    print(prediction)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
            
# After the loop release the cap object
cap.release()
# Destroy all the windows
cv2.destroyAllWindows()
# Out:
# Rock
# [[9.8829830e-01 4.0570647e-03 7.6433416e-03 1.2319560e-06]]
# 1/1 [==============================] - 0s 40ms/step
# Rock
# [[8.71932685e-01 2.47435495e-02 1.03319936e-01 3.76195408e-06]]
# 1/1 [==============================] - 0s 34ms/step
# Rock
# [[9.2855412e-01 8.5135363e-03 6.2929422e-02 2.8630923e-06]]
# 1/1 [==============================] - 0s 39ms/step
# Rock
# [[9.7376740e-01 6.7151892e-03 1.9516297e-02 1.0647196e-06]]
# 1/1 [==============================] - 0s 42ms/step
# Rock
# [[9.7577763e-01 7.9835812e-03 1.6237227e-02 1.5528076e-06]]
# 1/1 [==============================] - 0s 34ms/step
# Rock
# [[9.6289122e-01 9.1310497e-03 2.7976550e-02 1.2260638e-06]]
# 1/1 [==============================] - 0s 35ms/step
# Rock
# [[9.6289122e-01 9.1310497e-03 2.7976550e-02 1.2260638e-06]]
# 1/1 [==============================] - 0s 30ms/step
# Rock
# [[9.7391719e-01 9.1468589e-03 1.6934089e-02 1.7680927e-06]]
# 1/1 [==============================] - 0s 33ms/step
# Rock
# [[8.50170732e-01 2.80492809e-02 1.21775396e-01 4.62563821e-06]]
# 1/1 [==============================] - 0s 31ms/step
# Rock
# [[9.6299565e-01 6.8541723e-03 3.0148797e-02 1.2870792e-06]]
# 1/1 [==============================] - 0s 39ms/step
# Rock
# [[9.5121109e-01 1.1097344e-02 3.7689611e-02 1.9621646e-06]]
# 1/1 [==============================] - 0s 44ms/step
# Rock
# [[8.9531314e-01 2.2741459e-02 8.1939980e-02 5.3707054e-06]]
# 1/1 [==============================] - 0s 30ms/step
# Rock
# [[9.5941931e-01 7.9536792e-03 3.2624602e-02 2.3178995e-06]]
# 1/1 [==============================] - 0s 33ms/step
# Rock
# [[9.5941931e-01 7.9536792e-03 3.2624602e-02 2.3178995e-06]]
# 1/1 [==============================] - 0s 29ms/step
# Rock
# [[9.8653030e-01 2.8771339e-03 1.0592215e-02 3.5207063e-07]]
# 1/1 [==============================] - 0s 33ms/step
# Rock
# [[9.2754966e-01 8.0061490e-03 6.4441405e-02 2.7627229e-06]]
# 1/1 [==============================] - 0s 31ms/step
# Rock
# [[9.1646516e-01 1.6870094e-02 6.6662118e-02 2.6226644e-06]]
# 1/1 [==============================] - 0s 31ms/step
# Rock
# 1/1 [==============================] - 0s 28ms/step
# Rock
# [[9.1440779e-01 1.7054939e-03 8.3882928e-02 3.7779059e-06]]
# 1/1 [==============================] - 0s 26ms/step
# Rock
# [[8.5238570e-01 3.5976297e-03 1.4401057e-01 6.1087503e-06]]
# 1/1 [==============================] - 0s 27ms/step
# Rock
# [[8.5238570e-01 3.5976297e-03 1.4401057e-01 6.1087503e-06]]
# 1/1 [==============================] - 0s 25ms/step
# Rock
# [[8.7961441e-01 3.5358565e-03 1.1684365e-01 6.1762980e-06]]
# 1/1 [==============================] - 0s 26ms/step
# Rock
# [[8.2292646e-01 5.3640972e-03 1.7169897e-01 1.0411195e-05]]
# 1/1 [==============================] - 0s 24ms/step
# Rock
# [[9.0663415e-01 1.1684875e-03 9.2193246e-02 4.0562168e-06]]
# 1/1 [==============================] - 0s 31ms/step
# Rock
# [[9.0663415e-01 1.1684875e-03 9.2193246e-02 4.0562168e-06]]
# 1/1 [==============================] - 0s 30ms/step
# Rock
# [[8.9589471e-01 3.8353496e-03 1.0026672e-01 3.2623809e-06]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Local user\Desktop\ComputerVision\RockPaperScissors.ipynb Cell 1' in <cell line: 8>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Local%20user/Desktop/ComputerVision/RockPaperScissors.ipynb#ch0000000?line=11'>12</a> normalized_image = (image_np.astype(np.float32) / 127.0) - 1 # Normalize the image
#      <a href='vscode-notebook-cell:/c%3A/Users/Local%20user/Desktop/ComputerVision/RockPaperScissors.ipynb#ch0000000?line=12'>13</a> data[0] = normalized_image
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Local%20user/Desktop/ComputerVision/RockPaperScissors.ipynb#ch0000000?line=13'>14</a> prediction = model.predict(data)
#      <a href='vscode-notebook-cell:/c%3A/Users/Local%20user/Desktop/ComputerVision/RockPaperScissors.ipynb#ch0000000?line=14'>15</a> cv2.imshow('frame', frame)
#      <a href='vscode-notebook-cell:/c%3A/Users/Local%20user/Desktop/ComputerVision/RockPaperScissors.ipynb#ch0000000?line=15'>16</a> # Press q to close the window
#
# File c:\Users\Local user\miniconda3\envs\Computer_Vision\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Local user\miniconda3\envs\Computer_Vision\lib\site-packages\keras\engine\training.py:2002, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1995   except ValueError:
#    1996     warnings.warn(
#    1997         'Using Model.predict with MultiWorkerMirroredStrategy or '
#    1998         'TPUStrategy and AutoShardPolicy.FILE might lead to out-of-order '
#    1999         'result. Consider setting it to AutoShardPolicy.DATA.',
#    2000         stacklevel=2)
# -> 2002 data_handler = data_adapter.get_data_handler(
#    2003     x=x,
#    2004     batch_size=batch_size,
#    2005     steps_per_epoch=steps,
#    2006     initial_epoch=0,
#    2007     epochs=1,
#    2008     max_queue_size=max_queue_size,
#    2009     workers=workers,
#    2010     use_multiprocessing=use_multiprocessing,
#    2011     model=self,
#    2012     steps_per_execution=self._steps_per_execution)
#    2014 # Container that configures and calls `tf.keras.Callback`s.
#    2015 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\Local user\miniconda3\envs\Computer_Vision\lib\site-packages\keras\engine\data_adapter.py:1401, in get_data_handler(*args, **kwargs)
#    1399 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1400   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1401 return DataHandler(*args, **kwargs)
#
# File c:\Users\Local user\miniconda3\envs\Computer_Vision\lib\site-packages\keras\engine\data_adapter.py:1150, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1147 else:
#    1148   self._steps_per_execution = steps_per_execution
# -> 1150 adapter_cls = select_data_adapter(x, y)
#    1151 self._adapter = adapter_cls(
#    1152     x,
#    1153     y,
#    (...)
#    1162     distribution_strategy=tf.distribute.get_strategy(),
#    1163     model=model)
#    1165 strategy = tf.distribute.get_strategy()
#
# File c:\Users\Local user\miniconda3\envs\Computer_Vision\lib\site-packages\keras\engine\data_adapter.py:982, in select_data_adapter(x, y)
#     980 def select_data_adapter(x, y):
#     981   """Selects a data adapter than can handle a given x and y."""
# --> 982   adapter_cls = [cls for cls in ALL_ADAPTER_CLS if cls.can_handle(x, y)]
#     983   if not adapter_cls:
#     984     # TODO(scottzhu): This should be a less implementation-specific error.
#     985     raise ValueError(
#     986         "Failed to find data adapter that can handle "
#     987         "input: {}, {}".format(
#     988             _type_name(x), _type_name(y)))
#
# File c:\Users\Local user\miniconda3\envs\Computer_Vision\lib\site-packages\keras\engine\data_adapter.py:982, in <listcomp>(.0)
#     980 def select_data_adapter(x, y):
#     981   """Selects a data adapter than can handle a given x and y."""
# --> 982   adapter_cls = [cls for cls in ALL_ADAPTER_CLS if cls.can_handle(x, y)]
#     983   if not adapter_cls:
#     984     # TODO(scottzhu): This should be a less implementation-specific error.
#     985     raise ValueError(
#     986         "Failed to find data adapter that can handle "
#     987         "input: {}, {}".format(
#     988             _type_name(x), _type_name(y)))
#
# File c:\Users\Local user\miniconda3\envs\Computer_Vision\lib\site-packages\keras\engine\data_adapter.py:564, in CompositeTensorDataAdapter.can_handle(x, y)
#     561     return True
#     562   return _is_composite(v)
# --> 564 return (any(_is_composite(v) for v in flat_inputs) and
#     565         all(_is_tensor_or_composite(v) for v in flat_inputs))
#
# File c:\Users\Local user\miniconda3\envs\Computer_Vision\lib\site-packages\keras\engine\data_adapter.py:564, in <genexpr>(.0)
#     561     return True
#     562   return _is_composite(v)
# --> 564 return (any(_is_composite(v) for v in flat_inputs) and
#     565         all(_is_tensor_or_composite(v) for v in flat_inputs))
#
# File c:\Users\Local user\miniconda3\envs\Computer_Vision\lib\site-packages\keras\engine\data_adapter.py:557, in CompositeTensorDataAdapter.can_handle.<locals>._is_composite(v)
#     555   return True
#     556 # Support Scipy sparse tensors if scipy is installed
# --> 557 return _is_scipy_sparse(v)
#
# File c:\Users\Local user\miniconda3\envs\Computer_Vision\lib\site-packages\keras\engine\data_adapter.py:1667, in _is_scipy_sparse(x)
#    1665 def _is_scipy_sparse(x):
#    1666   try:
# -> 1667     from scipy.sparse import issparse  # pylint: disable=g-import-not-at-top
#    1669     return issparse(x)
#    1670   except ImportError:
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1002, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:945, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1439, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1411, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1544, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:147, in _path_stat(path)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
